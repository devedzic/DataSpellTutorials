# %% [markdown]
# # DataSpell tutorial 1 (JetBrains)

# %% [markdown]
# Developed after JetBrains' [DataSpell Quick Start Guide](https://www.jetbrains.com/help/dataspell/quick-start-guide.html).

# %%
a = 1 + 1
a
# Out:
# 2

# %% [markdown]
# Add some Pandas code.

# %%
import pandas as pd
kernel_stats = pd.read_csv('libraries_by_python_version.csv')
kernel_stats
# Out:
#         library  kernel_python 3.4  kernel_python 3.5  kernel_python 3.6  \
# 0         numpy              57564             578800            2108495
# 1    matplotlib              43181             438386            1625902
# 2        pandas              36357             346667            1530252
# 3       sklearn              14938             222672             912615
# 4            os              13200             176685             592084
# 5       seaborn               9578             105132             467280
# 6         scipy              12898             112992             402051
# 7          time               8722              86455             294717
# 8    tensorflow               4212             123837             269226
# 9        random               5325              75455             260000
# 10         math               6389              78262             245540
# 11          sys               7784              73858             250441
# ...

# %% [markdown]
# Add some visualizations.

# %%
import matplotlib.pyplot as plt
plt.pie(kernel_stats['total_count'], labels=kernel_stats['library'])
plt.show()
